# %% [markdown]
# <a href="https://colab.research.google.com/github/baruchais/Cleaning_and_Visualizing_Data/blob/main/Cleaning_and_Visualizing_Data_Workshop_Sp24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to the workshop! (Spring 2024 Edition)
# We will explore how to clean and visualize data with Baruch AIS!
# I hope you enjoy!

# %% [markdown]
# # Pandas and Numpy
# Documentation:
#
# *    https://pandas.pydata.org/docs/
# *    https://numpy.org/doc/
# *    https://www.kaggle.com/datasets/shivamb/netflix-shows (Dataset)

# %% [markdown]
# ### What is dirty data?
#
# It is data that can look faulty --> Data that inconsistent, inaccurate, or incomplete.
#
# ### So how do we fix this?
#
# Simple: Exploratory Data Analysis

# %% [markdown]
# EDA: Exploratory Data Analysis
#
# We do EDA to understand our data set and find patterns within it. We want to find its main characteristics.

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading in dataset
df=pd.read_csv("/netflix_titles.csv")
# checking the first 10 values
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
# checking last 10 values
df.tail(10)
# Out:
#      show_id     type               title                 director  \
# 8797   s8798  TV Show           Zak Storm                      NaN
# 8798   s8799    Movie            Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie               Zenda           Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie             Zinzana          Majid Al Ansari
# 8802   s8803    Movie              Zodiac            David Fincher
# 8803   s8804  TV Show         Zombie Dumb                      NaN
# 8804   s8805    Movie          Zombieland          Ruben Fleischer
# 8805   s8806    Movie                Zoom             Peter Hewitt
# 8806   s8807    Movie              Zubaan              Mozez Singh
#
#                                                    cast  \
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# ...

# %%
# seeing the shape of the data set
df.shape
# Out:
# (8807, 12)

# %%
# seeing what columns we have
list(df.columns)
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'release_year',
#  'rating',
#  'duration',
#  'listed_in',
#  'description']

# %%
# statistical overview
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
'''
First step  when cleaning data is to check for duplicate rows
The pandas function .duplicated() checks each row
to see if it is duplicated
'''
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %% [markdown]
# ### Why do you guys think about viewing duplicated data like this?
#
# ### Is it easy to see which rows are duplicated?
# (not really)

# %%
# finding amount of duplicated rows
df.duplicated().sum()
# Out:
# 0

# %%
# There are no duplicate rows to remove here
# If you want to remove duplicate, here is how it would be done
df=df.drop_duplicates()

# %%
# seeing the unique values to see duplicates but df.duplicates is better
df.nunique()
# Out:
# show_id         8807
# type               2
# title           8804
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %%
# Next step is to remove null values (null values are usually found when something is blank)
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
# Again just like before, it is hard to see which values have null values
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# We could also check for change in shape
df.shape
# Out:
# (8807, 12)

# %%
# lets drop the null values
df=df.dropna()

# %%
# change in shape
df.shape
# Out:
# (5332, 12)

# %%
# double checking we removed the values
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# # What else can we do if we dont want to drop a feature?
# We can also replace these values. If you have numerical data you have the option of filling it with 0 or any any other statistical measure. For strings, you can replace with a space '' or whatever word you want basically.
#
# *   df.fiillna()

# %%
# The next step is to check for sturctural errors; usally only happens in categorical features

# %%
# seeing the unique values
df.nunique()
# Out:
# show_id         5332
# type               2
# title           5330
# director        3945
# cast            5200
# country          604
# date_added      1453
# release_year      72
# rating            14
# duration         198
# listed_in        335
# description     5321
# dtype: int64

# %% [markdown]
# We can see that in this data set there is no structural errors.
#
# How do I know this?
#
# If we do have a structural error, you can just fix it by checking that row and using fillna() to change that value.

# %%
# Lets compare the before and after of our file
new_file_name = "cleaned_netflix_data.csv"

# Save the DataFrame as a new CSV file with a different name
df.to_csv(new_file_name, index=False)

print(f"The DataFrame has been saved as {new_file_name}")
# Out:
# The DataFrame has been saved as cleaned_netflix_data.csv

# %%
# Our final step is to check for outliers.
# In this case, we want to see the high and lows
df.describe()
# Out:
#        release_year
# count   5332.000000
# mean    2012.742123
# std        9.625831
# min     1942.000000
# 25%     2011.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2021.000000

# %% [markdown]
# Looking at our min and max, what surprises you? Did you expect these results?

# %% [markdown]
# Let's use some visualization to see this!

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# Now lets do some visulization
#
# Depending on what you want to do, there are different types of charts

# %%
# Data Visualization 1: Content type in percentage
content_counts = df['type'].value_counts(normalize=True) * 100
plt.figure(figsize=(8, 6))
content_counts.plot(kind='pie', autopct='%1.1f%%', colors=['skyblue', 'lightgreen'])
plt.title('Content Type Percentage')
plt.ylabel('')
plt.show()

# %%
# Data Visualization 2: Movie & TV Show by Country (Bar Chart)
country_counts = df['country'].value_counts().head(10)
plt.figure(figsize=(10, 6))
country_counts.plot(kind='bar', color='lightblue')
plt.title('Top 10 Countries with Most Content')
plt.xlabel('Country')
plt.ylabel('Number of Content')
plt.xticks(rotation=45)
plt.show()

# %%
# Data Visualization 4: Top Directors
top_directors = df['director'].value_counts().head(10)
plt.figure(figsize=(10, 6))
top_directors.plot(kind='barh', color='lightgreen')
plt.title('Top 10 Directors with Most Content')
plt.xlabel('Number of Content')
plt.ylabel('Director')
plt.show()

# %%
# Pair plot
plt.figure(figsize=(8, 6))
pairplot = sns.pairplot(df[['release_year', 'duration']], kind='scatter')

# Adjust x-axis limits for release year
pairplot.axes[0, 0].set_xlim(2000, 2025)

plt.suptitle('Pair Plot of Release Year and Duration', y=1.2)
plt.show()

# %% [markdown]
# # What else can we do?
#
# # Lets try to find a correlation with feature engineering?

# %% [markdown]
# # What is feature engineering?

# %% [markdown]
# Feature engineering is like choosing the right ingredients for a recipe. Just like you pick the best ingredients to make a dish tasty, in machine learning, you pick the right information (or “features”) from your data to help your model make good predictions.
#
# Sometimes, some ingredients (or “features”) don’t add any flavor to your dish (or “model”), so you leave them out. Other times, two ingredients might have the same flavor, so you only need one of them. This is what we do in feature engineering - we keep the useful features and remove the unnecessary ones to make our model work better.
#
# In short, feature engineering is all about selecting the best “ingredients” for your machine learning “recipe”.

# %%
from sklearn.preprocessing import LabelEncoder

# creating instance of labelencoder
labelencoder = LabelEncoder()

# Assigning numerical values and storing in another column
df['type_encoded'] = labelencoder.fit_transform(df['type'])
df['rating_encoded'] = labelencoder.fit_transform(df['rating'])

# Now you can create a correlation matrix
corr_matrix = df[['type_encoded', 'rating_encoded']].corr()

# And create a heatmap of this correlation matrix
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %% [markdown]
# This tells us that the correlation is not that strong (0.11 is closer to 0).

# %% [markdown]
# ## There are endless amounts of things you can do.
# ## We hope to see you agian in future events!
#
# ## Hope you enjoyed!
